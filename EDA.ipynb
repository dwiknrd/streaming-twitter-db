# %%
import pandas as pd
import sqlite3

# %%
con = sqlite3.connect('streaming_tweets.db')
con

# %%
pd.read_sql_query("SELECT * FROM tweets", con=con)
# Out:
#                 tweet_id       username  \
# 0    1416674227135029249     Ph_onemyat
# 1    1416674227889971201        gkachel
# 2    1416677923197751296      FleetNFFC
# 3    1416678970322558980  WriteWithDave
# 4    1416678972256043010       JP2010MN
# ..                   ...            ...
# 119  1418810211066855429        QP4Bell
# 120  1418810212270567426   Mark38182784
# 121  1418810216427163648        Opdiner
# 122  1418810217387659266       FloraMmn
# 123  1418810218394292228    AgSciWriter
#
#                                             tweet_text                 date  \
# 0    Covid-19 outbreak is very serious on the groun...  2021-07-18 08:20:30
# 1    Catching up on @insiders and yelling at Barnab...  2021-07-18 08:20:31
# 2                   There literally laughing at us all  2021-07-18 08:35:12
# 3    Does anyone remember what they were thinking a...  2021-07-18 08:39:21
# 4    @Pravduh15 @kylegriffin1 Data are collected in...  2021-07-18 08:39:22
# ...
